# %% [markdown]
# # Lab - 3 - Data Exploration

# %% [markdown]
# ### 1)  First, you need to read the titanic dataset from local disk and display first five records

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic.csv')

# %%
display(df.head(5))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 2)  Identify Nominal, Ordinal, Binary and Numeric attributes from data sets and display all values.

# %%
display(df.head(3))

# Nominal, Ordinal and Binary are Qualitative attributes.
# Numeric, Discrete and Continuous are Quantative attributes.

# Nominal attributes : it is related to name like Colors names, Human names etc.
# Ordinal attributes : its contains values that have a meaningful sequence or ranking(order) between them,
#                      but the magnitude between values is not actually known. 
# Binary attributes : it has only 2 data or states like yes/no, true/false, 0/1, male/female etc.
# Numeric attributes : its represented numeric value.

#                  Numerical attributes are of 2 types, interval, and ratio/range.
#                  Interval : Measured on a scale of equal-sized units like calendar dates (5-15), weight(70-85)
#                  Ratio/Range : it is a numeric attribute with a fix zero-point. like weight, height, marks, age etc.


# Here in this data set Name, Ticket, Embarked and Cabin are Nominal attribute,
# Pclass is Ordinal attribute, Survived & Sex are Binary attributes,
# Pclass, SibSp, Parch & Fare are Numeric attributes

# Unknown Column is also nominal attributes because its contains value not represent any class or any other value.
# Like 1,2,3 => 1 is Best, 2 is Average and 3 is dull
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ### 3)  Identify symmetric and asymmetric binary attributes from data sets and display all values.

# %%
display(df.head(5))

# Binary attributes : it has only 2 data or states like yes/no, true/false, 0/1, male/female etc.

# Symmetric: Both values are equally important (Male / Female). 
# Asymmetric: Both values are not equally important (Pass / Fail).
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 4)  For each quantitative attribute, calculate its average, standard deviation, minimum, mode, range and maximum values.

# %%
from pandas.api.types import is_numeric_dtype

for column in df.columns:
    if is_numeric_dtype(df[column]):
        print(column, ":")
        print("\t Mean = %.2f" % df[column].mean())
        print("\t Standard deviation = %.2f" % df[column].std())
        print("\t Minimum = %.2f" % df[column].min())
        if column != 'PassengerId' : print("\t Mode = %.2f" % df[column].mode())
        print("\t Range = %.2f" % (df[column].max() - df[column].min()))
        print("\t Maximum = %.2f" % df[column].max())
# Out:
# PassengerId :
# 	 Mean = 446.00
# 	 Standard deviation = 257.35
# 	 Minimum = 1.00
# 	 Range = 890.00
# 	 Maximum = 891.00
# Survived :
# 	 Mean = 0.38
# 	 Standard deviation = 0.49
# 	 Minimum = 0.00
# 	 Mode = 0.00
# 	 Range = 1.00
# 	 Maximum = 1.00
# Pclass :
# 	 Mean = 2.31
# 	 Standard deviation = 0.84
# 	 Minimum = 1.00
# 	 Mode = 3.00
# 	 Range = 2.00
# 	 Maximum = 3.00
# Age :
# 	 Mean = 29.70
# 	 Standard deviation = 14.53
# 	 Minimum = 0.42
# 	 Mode = 24.00
# 	 Range = 79.58
# 	 Maximum = 80.00
# SibSp :
# 	 Mean = 0.52
# 	 Standard deviation = 1.10
# 	 Minimum = 0.00
# 	 Mode = 0.00
# 	 Range = 8.00
# 	 Maximum = 8.00
# Parch :
# 	 Mean = 0.38
# 	 Standard deviation = 0.81
# 	 Minimum = 0.00
# 	 Mode = 0.00
# 	 Range = 6.00
# 	 Maximum = 6.00
# Fare :
# 	 Mean = 32.20
# 	 Standard deviation = 49.69
# 	 Minimum = 0.00
# 	 Mode = 8.05
# 	 Range = 512.33
# 	 Maximum = 512.33

# %% [markdown]
# ### 6)  For the qualitative attribute (class), count the frequency for each of its distinct values.

# %%
display(df['Pclass'].value_counts())
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ###  7) It is also possible to display the summary for all the attributes simultaneously in a table using the describe() function. If an attribute is quantitative, it will display its mean, standard deviation and various quantiles (including minimum, median, and maximum) values. If an attribute is qualitative, it will display its number of unique values and the top (most frequent) values.

# %%
display(df.describe(include='all'))
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# ### 8)  For multivariate statistics, you can compute the covariance and correlation between pairs of attributes.

# %%
display(df.cov())   # Covariance
# Out:
#               PassengerId  Survived     Pclass         Age      SibSp  \
# PassengerId  66231.000000 -0.626966  -7.561798  138.696504 -16.325843
# Survived        -0.626966  0.236772  -0.137703   -0.551296  -0.018954
# Pclass          -7.561798 -0.137703   0.699015   -4.496004   0.076599
# Age            138.696504 -0.551296  -4.496004  211.019125  -4.163334
# SibSp          -16.325843 -0.018954   0.076599   -4.163334   1.216043
# Parch           -0.342697  0.032017   0.012429   -2.344191   0.368739
# Fare           161.883369  6.221787 -22.830196   73.849030   8.748734
#
#                 Parch         Fare
# PassengerId -0.342697   161.883369
# Survived     0.032017     6.221787
# Pclass       0.012429   -22.830196
# Age         -2.344191    73.849030
# SibSp        0.368739     8.748734
# Parch        0.649728     8.661052
# Fare         8.661052  2469.436846

# %%
display(df.corr())   # Correlation
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# ### 9) Display the histogram for Age attribute by discretizing it into 8 separate bins and counting the frequency for each bin.

# %%
# %matplotlib inline

df.Age.hist(bins=8)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 10) A boxplot can also be used to show the distribution of values for each attribute.

# %%
df.boxplot(column=["Age", "Fare"],figsize=[5,3])
# Out:
# <AxesSubplot:>

# %%
display(df.describe(include='all'))
display(df.boxplot(figsize=[10,3]))
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %% [markdown]
# ### 11)  Display scatter plot for any 5 pair of attributes , we can use a scatter plot to visualize their joint distribution.

# %%
import matplotlib.pyplot as plt

x = df.Age
y = df.Fare
plt.scatter(x, y, marker='*', alpha=0.5)
plt.title("Scatter Plot")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.show()

# %%
import matplotlib.pyplot as plt
from pandas.api.types import is_numeric_dtype

fig, axes = plt.subplots(3, 2, figsize=(12,12))
index = 0
numericList = [column for column in df.columns if (is_numeric_dtype(df[column]) and column != 'PassengerId')]
colorsList = ['r', 'b', 'y', 'g', 'k', 'r', 'g', 'k', 'r']

print(numericList)

for i in range(3):
    for j in range(i+1,4):
        ax1 = int(index/2)
        ax2 = index % 2
        axes[ax1][ax2].scatter(df[numericList[i]], df[numericList[j]], color=colorsList[index])
        axes[ax1][ax2].set_xlabel(numericList[i])
        axes[ax1][ax2].set_ylabel(numericList[j])
        index = index + 1
# Out:
# ['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
